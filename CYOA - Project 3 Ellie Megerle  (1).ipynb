# %%
# Ellie Megerle - Project 3 - Choose Your Own Adventure 
# In this code, I will be providing the user with a choose your own adventure stroy \
# This stroy is inspired by the novelist Haruki Murakami 
print("Welcome to the Murakami CYOA! Please Enter your name to begin:")
input("Name:")
print("You are walking in a park located near the outside of Tokyo at night. The cool \nspring breeze gently touches the back of your neck. A white cat with a \nblack patch of fur the shape of a kidney crosses the path you are on.")
print("\n\nDo you follow the cat towards a tunnel or do you continue on your path?")
print("\n(1) Follow the cat.")
print("\n(2) Continue on your path.")
c1 = int(input("\nWhat do you do? Enter 1 or 2: "))
if c1 == 1: # choose 1 for the first binary 
    print("\nThe cat leads you towards a darkened, stone tunnel that leads through a \nhill. The cat's white fur disappears into the darkness of the tunnel. As you step into the tunnel, a damp, earthy smell overtakes you. You feel \nthat the ground is wet. The cat makes a sharp left turn down another \ncorridor of the tunnel. \n\nDo you follow, or continue straight into the \ntunnel?")
    print("\n(3) Follow the cat.")
    print("\n(4) Continue straight down the corridor.")
    c2 = int(input("\n What do you do? Enter 3 or 4: "))
    if c2 == 3: # choose option 3
        print("\nAs you follow the cat down the corridor, the water becomes as deep as your knees, the cat seems to walk on top of the water, however. \n\nDo you follow the cat or turn around?")
        print("\n(5) You think: I'm already this far, might as well continue on...and follow the cat as the water deepens.")
        print("\n(6) You think: This is insane!!!!! and get the heck out of that dark tunnel.")
        c3 = int(input("\nWhat do you do? Enter 5 or 6: "))
        if c3 == 5: #END, 5
            print("The cat eventually leads you into a room with all golden walls and speaks just this: When you come out of the strom, \nyou won't be the same person who walked in. That's what this storm's all about. \n\nTHE END!")
        else: # c3 == 6: #END, 6 
            print("You turn around, run as fast as you can to the nearest ramen shop, get some soup and try as hard as you possibly can to forget what happened.")
    else: #c2 == 4:
        print("\nAs you walk straight down the corridor, the water gets so deep that you are swimming. Suddenly, a current begins to pull \nyou. \n\nDo you climb up a ladder you see on the wall or do you let the current take you? ")
        print("\n(7) Take the ladder. ")
        print("\n(8) Let the current pull you further. ")
        c4 = int(input("\nWhat do you do? Enter 7 or 8: "))
        if c4 == 7: #END, 7
            print("\n The ladder takes you back to street level where you walk home, cold and wet. \n\nTHE END!")
        else: # c4 == 8: #END, 8
            print("\n The current eventually pulls you under and spits you out in a boggy marsh you have never seen before. You then walk back to your apartment confused. \n\nTHE END!")
else: # for the case that 2 is selected 
    print("\nYou continue down the gravel path in the park, and you come up to a deserted  playground. There is a man sitting at the top of the slide staring \nup at the moon. You follow his gaze and see that there are now two moons \nin the sky. The regular moon as well as a smaller, greenish lopsided moon next to it. \n\nDo you walk up to the man or do you turn back down the path \nand run?")
    print("\n(9) You walk up to the man. ")
    print("\n(10) You turn back down the path and run.")
    c5 = int(input("\nWhat do you do? Enter 9 or 10: "))
    if c5 == 9 :
        print("\nYou approach the strange man on top of the slide. \n\nDo you ask his name or do you ask him about the moons? ")
        print("\n(11) Ask him about his name.")
        print("\n(12) Ask him about the moons.")
        c6 = int(input("\nWhat do you do? Enter 11 or 12: "))
        if c6 == 11: #END, 11
            print("\nThe man replies with: Becoming a different person might be hard, but taking on a different name is a cinch.\n\nTHE END!")
        else: #END, 12
            print("\nThe man says nothing. He continues to stare at the moons. You join him - hypnotized by these moons and feeling relaxed somehow.\n\nTHE END!")
    else:# c5 == 10:
        print("\nAs you run down the path, the cat from before steps into the middle of the path. You stop. The cat says: Hello. \n\nDo you say hello back to him or do you keep running?")
        print("\n(13) Say hello to the cat.")
        print("\n(14) Run around it, keep running, this is too weird!")
        c6 ==int(input("\nWhat do you do? Enter 13 or 14: "))
        if c6 == 13: #END, 13
            print("\nThe cat then says to you: I think your shoe is untied, you better do something about that. You look down and the cat is right...your shoe is untied. You tie it. You head on your way into the night.\n\nTHE END!")
        else:# c6 == 14: #END, 14
            print("/nYou keep running until you get to your apartment. You immediately jump into the shower - cold - to wash off what you have just experienced.\n\nTHE END!")
# Out:
# Welcome to the Murakami CYOA! Please Enter your name to begin:
# Name:e
# You are walking in a park located near the outside of Tokyo at night. The cool
# spring breeze gently touches the back of your neck. A white cat with a
# black patch of fur the shape of a kidney crosses the path you are on.
#
#
# Do you follow the cat towards a tunnel or do you continue on your path?
#
# (1) Follow the cat.
#
# (2) Continue on your path.
#
# What do you do? Enter 1 or 2: 2
#
# You continue down the gravel path in the park, and you come up to a deserted  playground. There is a man sitting at the top of the slide staring
# up at the moon. You follow his gaze and see that there are now two moons
# in the sky. The regular moon as well as a smaller, greenish lopsided moon next to it.
#
# Do you walk up to the man or do you turn back down the path
# and run?
#
# (9) You walk up to the man.
#
# (10) You turn back down the path and run.
#
# What do you do? Enter 9 or 10: 9
#
# ...
