# %%
# importing libraries (Source: superheorPlots_Skeleton)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# displaying plots in a line (Source: superheorPlots_Skeleton)
# %matplotlib inline 

# specifying how to show the figures (Source: superheorPlots_Skeleton)
plt.rcParams["figure.figsize"] = (8,6)

# %%
# reading the csv and sorting it by date (Source: superheorPlots_Skeleton)
#shootings = pd.read_csv("shootings.csv", parse_dates = ["Date"])

# %%
# Importing image for the beginning of the project, this is copied from Data Science Parichay (https://datascienceparichay.com/article/insert-image-in-a-jupyter-notebook/)
from IPython.display import Image
Image(url = "cop_shooting.jfif", width=800, height=800)
# Out:
# <img src="cop_shooting.jfif" width="800" height="800"/>

# %% [markdown]
# # Shootings in the United States: A Data Set Over 50 Years
# ## by Ellie Megerle
# ## INFO 1201 Final Project
# Shootings in the United States of America have become a "normal" part of life. It is not uncommon for a shooting
# to occur every day of the year. This country represents just 5% of the world's population, however 31% of the world's
# shootings occur here, according to the LA Times. The topic of shootings in the US is highly divisive and dividing.
# Some Americans argue that guns should be banned, perhaps bought back by a government program, or even destroyed.
# Others are of the opinion that the government can remove their guns “over my dead body”. With both sides having logical
# and well formulated arguments, it may be hard for the average American (or non-American) to decide where to stand on
# this issue. Even more, the emotional aspect of mass shootings plays a large role in people’s attitudes. Nobody
# disagrees that mass (and non-mass) shootings are tragedies that should never happen, however, the road to a solution
# tends to be shrouded in opinions, rhetoric, and claims. In order to get to a solid solution, we must evaluate the data
# we have gathered. Philosopher George Santayana once said: “Those who do not remember the past are condemned to repeat
# it”, and that is the driving reason for gathering data on this topic (and many others). By gathering as much data
# as possible on every aspect of shootings that occur, we have a shot on being able to recognize signs of an imminent
# violent act before it occurs. This could save lives, if used correctly.

# %%
# Importing image for the quote section of the project, this is copied from Data Science Parichay (https://datascienceparichay.com/article/insert-image-in-a-jupyter-notebook/)
from IPython.display import Image
Image(url = "history.jfif", width=600, height=600)
# Out:
# <img src="history.jfif" width="600" height="600"/>

# %% [markdown]
# Quote by George Santayana

# %% [markdown]
# ## The Data Set
# The CSV file that is analyzed in this project is a compilation of mass shooting data dating back to 1966. One of the
# latest shootings in this file is the largest one in human history: the Las Vegas shooting that claimed 58 and injured
# 515 that occurred in October of 2017. Other pieces of data on the shootings and perpetrators that are compiled in
# this file are: location, target, fatalities, injured, age of shooter, and race of shooter. It is important to note
# that the definition of a mass shooting is a shooting in which four or more people are injured or killed. The
# owner of this dataset, Zeeshan-Ul-Hassan Usmani, has compiled data from Wikipedia, Mother Jones, Stanford, USA
# Today, among other internet sources. He has successfully gathered data on 398 mass shootings from 1966 to 2017.
# Although this dataset is extensive, the most common missing pieces of data are if the shooter was mentally ill
# or not. Of course, this is a very tough piece of data to gather and is often nuanced. Of course, someone
# committing this act of violence is not mentally sound, but the exact mental issue is often unknown, at least
# in this data gathering.

# %%
# Importing image for the abstraction section of the project, this is copied from Data Science Parichay (https://datascienceparichay.com/article/insert-image-in-a-jupyter-notebook/)
from IPython.display import Image
Image(url = "restoration.jfif", width=900, height=600)
# Out:
# <img src="restoration.jfif" width="900" height="600"/>

# %% [markdown]
# Source: Pinterest

# %% [markdown]
# ## Wiping the Dust Off
# Throughout the project, I was able to apply much of the computational thinking I have gained throughout my time learning
# Python. Because not every data set is perfect, clear-cut, and well organized, a coder usually must take time to “clean”
# the code before it is able to be put to good use. For example, each parameter in the CSV was investigated, binned
# accordingly, and labeled with a useful, clear-cut and understandable label. It’s like cleaning your room; A place for
# everything and everything in its place. For example, there were many “Targets” (victims) of the shootings in this
# database that needed to be cleaned up in order to be put into a nice-looking pie chart. I chose to group a lot of the
# target data points into one bin, “Other” which allowed me to create a pie chart of the top five victims
# (in relation to the shooter) of mass shootings. This process is called Abstraction. I hide the detail so the reader can
# get a good idea of what is happening. It is like restoring an old piece of art; scraping off all the dust, touching up the paint, and revealing the brillance and beauty of the painting below.

# %%
# Importing image for the debugging section of the project, this is copied from Data Science Parichay (https://datascienceparichay.com/article/insert-image-in-a-jupyter-notebook/)
from IPython.display import Image
Image(url = "cowboys.jfif", width=900, height=600)
# Out:
# <img src="cowboys.jfif" width="900" height="600"/>

# %% [markdown]
# Art by Mark Maggiori

# %% [markdown]
# ## Be The Cowboy
# There was some pretty significant debugging I had to go through to get my data to look and act like it should for the
# reader to understand what is going on. The first problem I ran into was getting the Excel file to act correctly. I kept
# getting the same errors, even though I had uploaded the file as a CSV. Turns out, I had to change it to a “CSV UTF-8
# (comma delimited)” file in order to get rid of the errors. This took some problem-solving algorithms such as Googling
# and researching databases! It was fun. Expressing the data in a way that made sense was also a challenge I was able to
# overcome eventually through many iterations of trial and error. At times, the data would go “crazy” and I would have to
# tame it down again like a cowboy. I had a lot of fun with this too, and I think I will use Python in the future to make
# my own data analyses for topics I am interested in. This allows me full control over the data set, with nobody else’s
# biases involved. I can learn to trust my own skills.

# %%
# counting all unique values of race
race_counts = shootings["Race"].value_counts()
race_counts
# Out:
# White American or European American                    122
# Black American or African American                      76
# Unknown                                                 42
# Some other race                                         20
# white                                                   12
# Asian American                                          11
# White                                                    9
# Asian                                                    6
# Latino                                                   5
# Black                                                    5
# Native American or Alaska Native                         3
# black                                                    3
# Two or more races                                        2
# Other                                                    2
# White American or European American/Some other Race      1
# Asian American/Some other race                           1
# ...

# %%
# grouping all the messsy data points into each section

# grouping black and white sets
race_shootings = shootings
race_shootings = race_shootings.replace("White American or European American", "White")
race_shootings = race_shootings.replace("white", "White")
race_shootings = race_shootings.replace("Black American or African American", "Black")
race_shootings = race_shootings.replace("black", "Black")
  
# grouping asian to one group 
race_shootings = race_shootings.replace("Asian American", "Asian")

# grouping some others...
race_shootings = race_shootings.replace("Two or more races", "Other")
race_shootings = race_shootings.replace("Asian American/Some other race", "Other")
race_shootings = race_shootings.replace("White American or European American/Some other Race", "Other")
race_shootings = race_shootings.replace("Some other race", "Other")

# grouping unknown
race_shootings = race_shootings.replace("Black American or African American/Unknown", "Unknown")

# grouping "Other" and "Unknown" for ease of dropping them
race_shootings = race_shootings.replace("Other", "DROP")
race_shootings = race_shootings.replace("Unknown", "DROP")

# deleting unknown and other (maybe I will use this later)
drop_race = race_shootings.drop(race_shootings[race_shootings.Race == "DROP"].index)

# updating the database 
race_counts = drop_race["Race"].value_counts()

# plotting in a pie chart
race_counts.plot(kind = "pie", colormap = "Purples", autopct = "%10.0f%%", fontsize = 14)
plt.title("Race Breakdown of USA Mass Shootings (where race is known)", fontsize = 18)

# removing that automatic y axis label
plt.axes().set_ylabel('')
# Out:
# <ipython-input-95-8442f4058914>:37: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.axes().set_ylabel('')
# Text(0, 0.5, '')

# %% [markdown]
# ## So, Which Race is Responsible for the Most Mass Shootings?
# An important question to ask is which races are perpetrating the most mass shootings. This is important in predicting which conditions lead to a mass shooting, including race. The question here is: What are the top five races that commit mass shootings? In order to answer this query I first had to clean the data. There were several redundant groupings that I melded together as well as grouping some vague boxes into a Other category as well as an Unknown category. Since I am doing only the top five, I used the drop function to remove these two categories.  I then updated the parsed database and plotted it using matplotlib in a pie chart. This resulted in a graph that had 57% of the shootings committed by White people, 33% Black, 7% Asian, 2% Latino and 1% Native American/ Alaska Native. Some possible limitations of this data are that a good number (around 80 of the incidents) were Unknown or Other. The total number of data points here is 398 shootings, so there is a possibility that this “lost” data could change the end results. I used the class notes and skeleton codes from class to help me complete this section. I also used my past projects.

# %%
# counting all unique values of target
target_counts = shootings["Target"].value_counts()
target_counts

#groupnig all but the top five targets into an "other" category
target_shootings = shootings
target_shootings = target_shootings.replace("Ex-Coworkers", "Other")
target_shootings = target_shootings.replace("party guests", "Other")
target_shootings = target_shootings.replace("Ex-Wife", "Other")
target_shootings = target_shootings.replace("Policeman", "Other")
target_shootings = target_shootings.replace("coworkers", "Other")
target_shootings = target_shootings.replace("neighbors", "Other")
target_shootings = target_shootings.replace("Ex-Wife & Family", "Other")
target_shootings = target_shootings.replace("school girls", "Other")
target_shootings = target_shootings.replace("Children", "Other")
target_shootings = target_shootings.replace("Ex-Girlfriend", "Other")
target_shootings = target_shootings.replace("police", "Other")
target_shootings = target_shootings.replace("Friends", "Other")
target_shootings = target_shootings.replace("Policeman+Council Member", "Other")
target_shootings = target_shootings.replace("Students+Parents", "Other")
target_shootings = target_shootings.replace("black men", "Other")
target_shootings = target_shootings.replace("women", "Other")
target_shootings = target_shootings.replace("House Owner", "Other")
target_shootings = target_shootings.replace("Ex-Girlfriend & Family", "Other")
target_shootings = target_shootings.replace("Social Workers", "Other")
target_shootings = target_shootings.replace("rapper+random", "Other")
target_shootings = target_shootings.replace("postmaster", "Other")
target_shootings = target_shootings.replace("Trooper", "Other")
target_shootings = target_shootings.replace("protestors", "Other")
target_shootings = target_shootings.replace("birthday party bus", "Other")
target_shootings = target_shootings.replace("Girlfriend", "Other")
target_shootings = target_shootings.replace("hunters", "Other")
target_shootings = target_shootings.replace("Congresswoman", "Other")
target_shootings = target_shootings.replace("psychologist+psychiatrist", "Other")
target_shootings = target_shootings.replace("welding shop employees", "Other")
target_shootings = target_shootings.replace("prayer group", "Other")
target_shootings = target_shootings.replace("drug dealer", "Other")
target_shootings = target_shootings.replace("Family+random", "Other")
target_shootings = target_shootings.replace("Ex-GirlFriend", "Other")
target_shootings = target_shootings.replace("club members", "Other")
target_shootings = target_shootings.replace("Marines", "Other")
target_shootings = target_shootings.replace("partner's family", "Other")
target_shootings = target_shootings.replace("Sikhs", "Other")
target_shootings = target_shootings.replace("Ex-Girlfriend+random", "Other")
target_shootings = target_shootings.replace("Family/Neighbors", "Other")
target_shootings = target_shootings.replace("Family+students", "Other")
target_shootings = target_shootings.replace("TSA Officer", "Other")
target_shootings = target_shootings.replace("monks", "Other")
target_shootings = target_shootings.replace("Contestant", "Other")
target_shootings = target_shootings.replace("Ex-girlfriend", "Other")
target_shootings = target_shootings.replace("uninvited guests", "Other")
target_shootings = target_shootings.replace("lawyers", "Other")
target_shootings = target_shootings.replace("Coworker's Family", "Other")
target_shootings = target_shootings.replace("basketball players", "Other")

# grouping students and teachers 
target_shootings = target_shootings.replace("Teachers", "Students+Teachers")
target_shootings = target_shootings.replace("Students", "Students+Teachers")


# captializing random so it looks better on the graph
target_shootings = target_shootings.replace("random", "Random")

# counting all unique values of target
target_shootings = target_shootings["Target"].value_counts()
target_shootings

# plotting in a pie chart
target_shootings.plot(kind = "pie", colormap = "Blues", autopct = "%10.0f%%", fontsize = 14)
plt.title("Target Breakdown of USA Mass Shootings (Top Five)", fontsize = 18)

# removing that automatic y axis label
plt.axes().set_ylabel('')
# Out:
# <ipython-input-111-ed7d9e704d8b>:73: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.axes().set_ylabel('')
# Text(0, 0.5, '')

# %% [markdown]
# ## What are the Top Five Targets of Mass Shootings?
# My second query asked a similar question: What are the top five targets of mass shooters? This query required the most cleaning of any of the others throughout the project. There were over fifty categories for this section, many of them with only one or two tallies. This would obviously make for a very confusing and unhelpful pie chart. I grouped many of these (47 to be exact) in a Other category. Some of the categories I added to Other are: hunters, Marines, monks, postmaster, drug dealer, TSA Officers, and contestants. Next, I grouped the students and teachers category into one group because they would typically be induced in the same event. I also did some editing like capitalizing titles of sections here as well. I then updated the category counts, graphed, and titled my graph. The results are as follows: 44% Random victims, 28% Other, 12% Family, 11% Students and Teachers, and 5% Coworkers. This can give some insight as to who is at most risk when an unhinged person is likely to commit an act of violence. Unfortunately, it seems that most of the victims will be random. A possible issue with this data set could be that there are far too many categories to make any strong convictions. Again, I used class notes and past projects  to compile this graph.

# %%
# 3rd graph 
# counting all unique values of gender
gender_counts = shootings["Gender"].value_counts()

# cleaning the data, as always
gender_shootings = shootings 
gender_shootings = gender_shootings.replace("M", "Male")
gender_shootings = gender_shootings.replace("Male/Female", "Other/Unknown")
gender_shootings = gender_shootings.replace("M/F", "Other/Unknown")
gender_shootings = gender_shootings.replace("Unknown", "Other/Unknown")


# re counting database 

gender_shootings = gender_shootings["Gender"].value_counts()

# %%
# plotting in a pie chart
gender_shootings.plot(kind = "pie", colormap = "Oranges", autopct = "%10.0f%%", fontsize = 14)
plt.title("Gender Breakdown of USA Mass Shootings", fontsize = 18)

# removing that automatic y axis label
plt.axes().set_ylabel('')
# Out:
# <ipython-input-106-397339f1e0a2>:6: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.axes().set_ylabel('')
# Text(0, 0.5, '')

# %% [markdown]
# ## What Genders are Most Likely to Commit Mass Shootings?
# The third and final pie chart asks: What genders are the most likely to commit a mass shooting? This section of data only included a handful of categories, so the data was very easy to clean up. I just had to group the different categories for Male into one as well as group the unknowns together. I ended up with three groups to work with: Male, Female, and Unknown/ Other. After cleaning, I grouped the data again and graphed in a pie chart type. The results were striking with 90% of mass shootings being perpetrated by men, only 2% by women, and 8% is unknown or other. Obviously, there is an overwhelming conclusion for this query. However, that 8% is still unknown. A possible hole in the data arises here because we do not know what these people identify as. This could hide a trend, or it may not. I used class notes and my past projects to help here.
