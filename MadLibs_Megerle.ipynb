# %%
# She
# She screams in silence
# A sullen roit penetrating through her mind
# Waiting for a sign to smash the silence with the brick of self control
# Are you locked up in a world that's been planned out for you?
# Are you feeling like a social tool without a use?
# Scream at me until my ears bleed
# I'm taking heed just for you
# She
# She's figured out
# All her doubts were someone else's point of view
# Waking up this time to smash the silence with the brick of self control
# Are you locked up in a world that's been planned out for you?
# Are you feeling like a social tool without a use?
# Scream at me until my ears bleed
# I'm taking heed just for you
# Are you locked up in a world that's been planned out for you?
# Are you feeling like a social tool without a use?
# Scream at me until my ears bleed
# I'm taking heed just for you

# -------------------------GREENDAY'S "SHE" IS THE SAMPLE TEXT I AM USING HERE -----------------------
# Here is the same song with some of the words removed (also I am onnly using the first verse): 

# She
# She _____(verb 1) in ________(adjective 1)
# A sullen ____(noun 1) penetrating through her mind
# Waiting for a sign to smash the _______(adjective 1 again) with the _____(noun 2) of self control
# Are you locked up in a ____(noun 3) that's been planned out for you?
# Are you feeling like a social _________(noun 4) without a use?
# Scream at me until my _____(noun 5, body part) bleed
# I'm taking heed just for you
# She
# She's figured out
# All her doubts were someone else's point of view
# Waking up this time to smash the _______(adjective 1 again) with the ____(noun 2) of self control
# Are you locked up in a ____(noun 3) that's been planned out for you?
# Are you feeling like a _______(noun 4) without a use?
# Scream at me until my ______(noun 5, body part) bleed
# I'm taking heed just for you
# Are you locked up in a ______(noun 3) that's been planned out for you?
# Are you feeling like a _______(noun 4) without a use?
# Scream at me until my _____(noun 5, body part) bleed
# I'm taking heed just for you
verb1 = input ("Give me a one syllable plural verb ")   # asking for the first verb to replace "screams"
adj1 = input ("Give me a two syllable adjective ")      # asking for the first adjective to replace "silence"
noun1 = input("Give me a two syllable noun! ")           # asking for the first noun to replace "riot"
noun2 = input("Give me a one syllable noun ")      # asking for the second noun to replace "brick"
noun3 = input("Another noun, one syllable ")   # asking for the thrid noun to replace "world"
noun4 = input("A noun, one single syllable ")          # asking for the fourth noun to replace "social tool"
noun5 = input("A  one syllable plural noun, but this time a body part ") # asking for the fifth and final noun to reoplace "ears"
input = ("are you ready to get your custom made song?")           # asks user a question, but the answer is purely for asthetics. I don't like how the lyrics pop up so quickly
print("  ")  # spacing
print("  ")  # spacing 
print("She - Green Day") # title
print("  ") # spacing 
# ------------ the rest of the code is just concatonating the inputs with the original lyrics to create the custom song --------------
print("She, She " + verb1 + " in " + adj1) 
print("A sullen " + noun1 + " penetrating through her mind")
print("Waiting for a sign to smash the " + adj1 + " with the " + noun2 +" of self control")
print("Are you locked up in a " + noun3 + " that's been planned out for you?")
print("Are you feeling like a social " + noun4 + " witohut a use?")
print("Scream at me until my " + noun5 + " bleed")
print("I'm taking heed just for you")
print("  ")
print("She, She's figured out")
print("All her doubts were someone else's point of view")
print("Waking up this time to smash the " + adj1 + " with the " + noun2 + " of self control")
print("Are you locked up in a " + noun3 + " that's been planned out for you?")
print("Are you feeling like a social " + noun4 + " witohut a use?")
print("Scream at me until my " + noun5 +" bleed")
print("I'm taking heed just for you")
print("  ")
print("Are you locked up in a " + noun3 + " that's been planned out for you?")
print("Are you feeling like a social " + noun4 + " witohut a use?")
print("Scream at me until my " + noun5+ " bleed")
print("I'm taking heed just for you")
print("  ")
print("  ")
print("  ")
print("Thank you for playing!!!") # thanks user for playing
# Out:
# Give me a one syllable plural verb screams
# Give me a two syllable adjective silence
# Give me a two syllable noun! noun
# Give me a one syllable noun noun
# Another noun, one syllable noun
# A noun, one single syllable noun
# A  one syllable plural noun, but this time a body part nouns
#
#
# She - Green Day
#
# She, She screams in silence
# A sullen noun  penetrating through her mind
# Waiting for a sign to smash the silence with the noun  of self control
# Are you locked up in a noun  that's been planned out for you?
# Are you feeling like a social noun  witohut a use?
# Scream at me until my nouns bleed
# I'm taking heed just for you
#
# She, She's figured out
# All her doubts were someone else's point of view
# Waking up this time to smash the silence with the noun  of self control
# Are you locked up in a noun  that's been planned out for you?
# Are you feeling like a social noun  witohut a use?
# Scream at me until my nouns bleed
# I'm taking heed just for you
#
# ...
