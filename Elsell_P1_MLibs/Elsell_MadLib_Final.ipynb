# %%
'''
Zain Elsell
6/16/21


Required Libraries below:
install pyttsx3 w/ "pip install pyttsx3" in conda terminal or normal terminal if using linux or OSX.
intsall coloroma w/ "pip install colorama"


=Notes=
Colorama only works sometimes so I've left the code in I think the reason for that is because the program calls init from
pyttsx3 and init from colorama and they don't like to play nice with eachother. For now i'm gonna call this good maybe revisit 
it at a later date. Thats what all the f.BLUE or b.Red + "string" stuff is calling in the code.

I made the majority of this project under a strict time limit due to a power outtage that took place at 10pm so that
brings me to....

Cut Features:

play the the chords of the song if the text to speech is enable with the playsound 1.2.2 library "pip install playsound". 
I couldn't find a insturmental verison of the song so I couldn't go that route alternatively could have recorded the chords
but time.

play the chords of the song using the mignus library and some midi files. Could have done this but ran out of time.

Use buetiful soup to pull random verbs, adj, etc from the oxford dictionary web crawling the dict with bueatiful soup.


=Credits=

Used this guide as refrence for coloroma: https://www.geeksforgeeks.org/print-colors-python-terminal/
Used this as refrence on how to kill the program https://www.stechies.com/end-python-program/

Along with these documentations: 
https://pypi.org/project/colorama/, https://pypi.org/project/pyttsx3/, https://pypi.org/project/goto/

Song Lyrics can Be found here:
https://genius.com/Days-n-daze-to-risk-to-live-lyrics

You can stream the original song here:
https://open.spotify.com/track/0YG5wOXVpvNUyPihvr1zsa?si=f146c611ec7c47a0


'''


import pyttsx3 as tlk;
from colorama import Fore as f, Back as b, Style as s, init# as colorInit
import sys

# %%
#colorama.init(autoreset= True) #Resets the color back to defualt automatically from line to line

print("Welcome to mad libs today today we are gonna change part of the lyrics to To Risk to Live by Days n Daze. \n")
#print(f.BLUE + 'Lines that have your input on are put in blue like this!')
name= input("To start can I have your name? \n")
print ( "Nice to meet you " + name + " lets start the game!")
        
tts = 0
ttsPrompt = input("Would you like to enable text to speech? y/n \n")
if ttsPrompt == "y":
    tts = 1 #Set text to speech var to 1 or enabled
    sp = tlk.init() #intailize speech engine
    print ("Text to speech enabled. \n") #print confirmation
    sp.say('Text to speech enabled. ') #enter string to say
    sp.runAndWait()    #run text through speech engine
elif ttsPrompt == "n":
    tts = 0
    print ("Text to speech disabled. \n")
else:
    print(b.RED + "Invalid input type y or n and run the program again.")
    sys.exit(0) #Kill program if the user inputs something other then y or n
    



noun1 = input("Give me a loction: \n")
noun2 = input("Give me another noun (like mercy): \n")
transVerb1 = input("Give me a transitive verb: \n")
adj1 = input("Give me an adjective (Present Tense): \n")
verb1 = input("Give me a food: \n")
gpa = input("Give me a gpa: \n")
verb2 = input("Give me a object: \n")



if tts == 0: #tts is false
    #print out the song with no text to speech
    print("\n")
    print("She said, I’ve got two kids and a grave plot")
    print("Right next to my day job")
    print("And my husbands grave is parallel to mine")
    print(f.BLUE +"And when we die we’ll go to " + noun1)
    print ("Because we spent our whole lives begging")
    print (f.BLUE + "For " + noun2 + "from some old man in the sky \n")

    print("I said, 'Well doesn't that seem silly When theres so much left to see and do?'")
    print("Don't get me wrong")
    print("Just be yourself")
    print("But darlin, bet if I where you i'd go on cut the losses")
    print(f.BLUE + "burn the bills say " + transVerb1 +" the bosses'")
    print(f.BLUE + "and live a life " + adj1 + " and new \n")

    print(f.BLUE +"Well I met a college student named " + name + " at the library last week")
    print(f.BLUE +"Eating " + verb1 + " and crammin' for a test.")
    print(f.BLUE +"He said, 'Sorry I can't talk right now If I dont get a " + gpa + " I'll never get a good job like my dad!'")
    print(f.BLUE +"I said, Don't work for you entire life just to save up for a " + verb2)
    print("Dont put too much stake into your grades and rank")
    print("Just realize and remeber there's other place to travel to then your job, the supermarket, and the bank!")

    print("Don’t waste your best years")
    print("Just livin’ for somebody else") 
    print ("Don’t waste your best years" )
    print ("Just hidden behind a desk") 
    print("Don’t waste your best years")
    print("They’re the only ones you’ll ever get")
    print("So why not play life closer to the chest?")
    
elif tts == 1: #tts is true
    
    #these strings run the text to speech an are just long concatinations of the entire song
    verse1 = "She said, I’ve got two kids and a grave plot Right next to my day job And my husbands grave is parallel to mine And when we die we’ll go to " + noun1 + "Cause we spent our whole lives begging For " + noun2 + " from some old man in the sky I said, Well doesn’t that seem silly When there's so much left to see and do? Don’t get me wrong Just be yourself But darlin’, bet if I were you I'd go on, cut my losses Burn the bills, say "+ transVerb1 + " the bosses! And live a life "+ adj1 +" and new," 
    verse2 = "Well I met a college student named " + name + " At the library last week eating " + verb1 + " and crammin’ for a test He said, I’m sorry but I can’t talk right now If I don’t get a" + gpa + " I’ll never get a good job like my dad! I said, Don’t work for your entire life Just to save up for a " + verb2 + "Don’t put too much stake into your grades and rank Just realize and remember: There’s other places to travel to Than your job, the supermarket and the bank Don’t waste your best years Just livin’ for somebody else Don’t waste your best years Just hidden behind a desk Don’t waste your best years They’re the only ones you’ll ever get. So why not play life closer to the chest?"
    
    #print out the song with test to speech enabled
    print("\n")
    print("She said, I’ve got two kids and a grave plot")
    print("Right next to my day job")
    print("And my husbands grave is parallel to mine")
    print(f.BLUE +"And when we die we’ll go to " + noun1)
    print ("Because we spent our whole lives begging")
    print (f.BLUE + "For " + noun2 + " from some old man in the sky \n")

    print("I said, 'Well doesn't that seem silly When theres so much left to see and do?'")
    print("Don't get me wrong")
    print("Just be yourself")
    print("But darlin, bet if I where you i'd go on cut the losses")
    print(f.BLUE + "burn the bills say " + transVerb1 +" the bosses'")
    print(f.BLUE + "and live a life " + adj1 + " and new \n")

    print(f.BLUE +"Well I met a college student named " + name + " at the library last week")
    print(f.BLUE +"Eating " + verb1 + " and crammin' for a test.")
    print(f.BLUE +"He said, 'Sorry I can't talk right now If I dont get a " + gpa + " I'll never get a good job like my dad!'")
    print(f.BLUE +"I said, Don't work for you entire life just to save up for a " + verb2)
    print("Dont put too much stake into your grades and rank")
    print("Just realize and remeber there's other place to travel to then your job, the supermarket, and the bank!")
    
    print("\n")
    print("Don’t waste your best years")
    print("Just livin’ for somebody else") 
    print ("Don’t waste your best years" )
    print ("Just hidden behind a desk") 
    print("Don’t waste your best years")
    print("They’re the only ones you’ll ever get")
    print("So why not play life closer to the chest?")
    
    sp.say(verse1) #say verse 1 of the song
    sp.say(verse2) #say verse 2 of the song
    sp.runAndWait() # run through speech engine


else: #idk an edge case or something I don't even know how the user would get here but if they do something went so wrong
    print(b.RED + "===================FATAL ERROR=====================")
    sys.exit(-1)
# Out:
# Welcome to mad libs today today we are gonna change part of the lyrics to To Risk to Live by Days n Daze.
#
# To start can I have your name?
# e
# Nice to meet you e lets start the game!
# Would you like to enable text to speech? y/n
# e
# Invalid input type y or n and run the program again.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# C:\Users\zaine\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3445: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
